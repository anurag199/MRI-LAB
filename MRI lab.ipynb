# %% [markdown]
# # 1  DICOM images are opened and rendered that were obtained from the lab

# %%
# %matplotlib inline
from skimage import novice, data, io, exposure
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
#the simplest way to open and display an image uses the novice module from skimage
brainpic = novice.open('egg (1).png')
brainpic.show()

# %% [markdown]
# Image of egg

# %%
# %matplotlib inline
from skimage import novice, data, io, exposure
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
#the simplest way to open and display an image uses the novice module from skimage
brainpic = novice.open('wat.png')
brainpic.show()

# %% [markdown]
# Image of watermelon and corn

# %%
# %matplotlib inline
from skimage import novice, data, io, exposure
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
#the simplest way to open and display an image uses the novice module from skimage
brainpic = novice.open('tomat.png')
brainpic.show()

# %% [markdown]
# Image of tomato

# %% [markdown]
# # 2 .  From the Metadata in the DICOM describe the type of MR sequence and the sequence param-eters that were used to acquire the image(s). Describe at minimum 5 parametersand briefly explain what those parameters refer to

# %%
# %matplotlib inline
from skimage import novice, data, io, exposure
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import dicom

#it is possible that in some installations pyDICOM won't be available in which case you will have to install it through pip

# Get file
RefDs = dicom.read_file('IM_0013.dcm')
# Let's print all the Metadata here
print(RefDs)
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M_FFE', 'M', 'FFE']
# (0008, 0012) Instance Creation Date              DA: '20171115'
# (0008, 0013) Instance Creation Time              TM: '111932'
# (0008, 0014) Instance Creator UID                UI: 1.3.46.670589.11.34055.5
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.46.670589.11.34055.5.0.4164.2017111510391773026
# (0008, 0020) Study Date                          DA: '20171115'
# (0008, 0021) Series Date                         DA: '20171115'
# (0008, 0022) Acquisition Date                    DA: '20171115'
# (0008, 0023) Content Date                        DA: '20171115'
# (0008, 0030) Study Time                          TM: '102824'
# (0008, 0031) Series Time                         TM: '103832.39000'
# ...

# %% [markdown]
# # Scanning Sequence
#
# Scanning sequence is 'GR' which is known as Gradient Echo.
#
# Pixel Spacing :-
#
# This attribute identifies physical distance in the patients body between the center of each pixel.
#
# Image Orientation :-
#
# This attribute identifies the direction of cosines of the first row and first column with respect to the patient body.
#
# Image Position :-
#
# This attribute identifies the x,y and z co-ordinates of the upper left hand side corner image of the patients body.
#
# Slice Location :-
#
# This attribute provides the respective position of image plane in millimeters.
#
# Inversion recovery pulse sequences:-
#
# This are used to give heavy T1-weighting. The basic part of an
# inversion recovery sequence is a 180 degree RF pulse that inverts the magnetization followed by a 90
# degree RF pulse that brings the residual longitudinal magnetization into the x-y or transverse plane where
# it can be detected by an RF coil.

# %% [markdown]
# # 3 What is the difference between the Acquisition Matrix that you can find in your Metadata and the number of pixels that your image has?  Investigate why is there a difference and briefly explain.

# %% [markdown]
# Acquisition Matrix obtained is [0, 256, 128, 0]
#
# The pixel information is 256 rows and 256 columns.
#
# Acquisition matrix is the number of independent data samples in every direction. It has distinct values in frequency and phase domains. Pixel information remains constant while, constructing as well as reconstructing whereas acquisition matrix can have different values.

# %% [markdown]
# # 4  What is the frequency that is listed in the Metadata referring to?  Would you expect this value to change with different scanners?  What would make this value change?  Explain briefly

# %% [markdown]
# Imaging frequency obtained is 127.753897.
#
# The frquency listed in the meta data is referring to imaging frequency.
#
# Yes it is expected that the value of imaging frequency will change with different scanners manufactured by different manufacturers.
#
# The parameters selected by different scanners make changes in the value of imaging frequency.

# %% [markdown]
# # 5 Briefly discuss any observations and issues during acquisition

# %% [markdown]
# During the session of performing MRI on different non living things we have used different size of coils for the reading, As our subject were non living there was no issue of noise in the reading as the subject were not moving. In the laboratory where the largest size coil was placed we were restricted to take metallic materials which can be attracted to the coil during the MRI reading
